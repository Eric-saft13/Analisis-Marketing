# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# 1. ACCESO DE DATOS Y PREPARACION PARA ANALISIS

# %%
import pandas as pd
import matplotlib.pyplot as plt

visits = pd.read_csv('/datasets/visits_log_us.csv')
orders = pd.read_csv('/datasets/orders_log_us.csv')
costs = pd.read_csv('/datasets/costs_us.csv')

# %%
visits['Start Ts'] = pd.to_datetime(visits['Start Ts'])
visits['End Ts'] = pd.to_datetime(visits['End Ts'])
visits['Uid'] = pd.to_numeric(visits['Uid'], errors='coerce', downcast='unsigned')
visits['Source Id'] = pd.to_numeric(visits['Source Id'], errors='coerce', downcast='integer')

orders['Buy Ts'] = pd.to_datetime(orders['Buy Ts'])
orders['Revenue'] = pd.to_numeric(orders['Revenue'], errors='coerce')
orders['Uid'] = pd.to_numeric(orders['Uid'], errors='coerce', downcast='unsigned')

costs['dt'] = pd.to_datetime(costs['dt'])
costs['costs'] = pd.to_numeric(costs['costs'], errors='coerce')
costs['source_id'] = pd.to_numeric(costs['source_id'], errors='coerce', downcast='integer')

# %%
print(visits.dtypes)
# Out:
# Device               object
# End Ts       datetime64[ns]
# Source Id              int8
# Start Ts     datetime64[ns]
# Uid                  uint64
# dtype: object

# %%
print(visits.head())
# Out:
#     Device              End Ts  Source Id            Start Ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
#
#                     Uid
# 0  16879256277535980062
# 1    104060357244891740
# 2   7459035603376831527
# 3  16174680259334210214
# 4   9969694820036681168

# %%
print(orders.dtypes)
# Out:
# Buy Ts     datetime64[ns]
# Revenue           float64
# Uid                uint64
# dtype: object

# %%
print(orders.head())
# Out:
#                Buy Ts  Revenue                   Uid
# 0 2017-06-01 00:10:00    17.00  10329302124590727494
# 1 2017-06-01 00:25:00     0.55  11627257723692907447
# 2 2017-06-01 00:27:00     0.37  17903680561304213844
# 3 2017-06-01 00:29:00     0.55  16109239769442553005
# 4 2017-06-01 07:58:00     0.37  14200605875248379450

# %%
print(costs.dtypes)
# Out:
# source_id              int8
# dt           datetime64[ns]
# costs               float64
# dtype: object

# %%
print(costs.head())
# Out:
#    source_id         dt  costs
# 0          1 2017-06-01  75.20
# 1          1 2017-06-02  62.25
# 2          1 2017-06-03  36.53
# 3          1 2017-06-04  55.00
# 4          1 2017-06-05  57.08

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente manejo inicial de los datos. Has aplicado correctamente la conversión de tipos de datos y has verificado los resultados con .dtypes y .head(), lo cual es una buena práctica. También has usado errors='coerce' al convertir, lo que previene errores inesperados. ¡Muy bien!
#
# </div>

# %% [markdown]
# 2. INFORMES Y CALCULO DE METRICAS

# %%
# 2.1 Visitas
daily_users = visits.groupby(visits['Start Ts'].dt.date)['Uid'].nunique()
weekly_users = visits.groupby(visits['Start Ts'].dt.to_period('W'))['Uid'].nunique()
monthly_users = visits.groupby(visits['Start Ts'].dt.to_period('M'))['Uid'].nunique()

print('Daily Users')
print(daily_users.head())
print('Weekly Users')
print(weekly_users.head())
print('Monthly Users')
print(monthly_users.head())
# Out:
# Daily Users
# Start Ts
# 2017-06-01    605
# 2017-06-02    608
# 2017-06-03    445
# 2017-06-04    476
# 2017-06-05    820
# Name: Uid, dtype: int64
# Weekly Users
# Start Ts
# 2017-05-29/2017-06-04    2021
# 2017-06-05/2017-06-11    4129
# 2017-06-12/2017-06-18    2812
# 2017-06-19/2017-06-25    2878
# 2017-06-26/2017-07-02    3064
# Freq: W-SUN, Name: Uid, dtype: int64
# Monthly Users
# Start Ts
# 2017-06    13259
# 2017-07    14183
# 2017-08    11631
# 2017-09    18975
# 2017-10    29692
# Freq: M, Name: Uid, dtype: int64

# %%
daily_sessions = visits.groupby(visits['Start Ts'].dt.date).size()
print(daily_sessions.head())
# Out:
# Start Ts
# 2017-06-01    664
# 2017-06-02    658
# 2017-06-03    477
# 2017-06-04    510
# 2017-06-05    893
# dtype: int64

# %%
visits['session_duration_min'] = (visits['End Ts'] - visits['Start Ts']).dt.total_seconds() / 60
print(visits.head())
# Out:
#     Device              End Ts  Source Id            Start Ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
#
#                     Uid  session_duration_min
# 0  16879256277535980062                  18.0
# 1    104060357244891740                  28.0
# 2   7459035603376831527                   0.0
# 3  16174680259334210214                  24.0
# 4   9969694820036681168                   0.0

# %%
user_visit_count = visits.groupby('Uid').size().reset_index(name='visit_count')
print(user_visit_count.head())
# Out:
#                Uid  visit_count
# 0   11863502262781            1
# 1   49537067089222            1
# 2  297729379853735            1
# 3  313578113262317            3
# 4  325320750514679            2

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Muy buen uso de groupby() con .dt.date y .dt.to_period() para calcular usuarios únicos diarios, semanales y mensuales. También el cálculo de duración de sesiones está correctamente planteado. El uso de .size() para contar sesiones también está bien aplicado. Buen enfoque analítico.
#
# </div>

# %%
# 2.2 Ventas
first_purchase = orders.groupby('Uid')['Buy Ts'].min().reset_index()
first_purchase.columns = ['Uid', 'first_purchase_date']
print(first_purchase.head())
# Out:
#                 Uid first_purchase_date
# 0   313578113262317 2018-01-03 21:51:00
# 1  1575281904278712 2017-06-03 10:13:00
# 2  2429014661409475 2017-10-11 18:33:00
# 3  2464366381792757 2018-01-28 15:54:00
# 4  2551852515556206 2017-11-24 10:14:00

# %%
orders_per_day = orders.groupby(orders['Buy Ts'].dt.date).size().reset_index(name='orders_count')
print(orders_per_day.head())
# Out:
#        Buy Ts  orders_count
# 0  2017-06-01            96
# 1  2017-06-02           111
# 2  2017-06-03            67
# 3  2017-06-04            66
# 4  2017-06-05           161

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Has hecho un gran trabajo identificando la primera compra y calculando el LTV. Como mejora, podrías haber comentado cómo estas métricas contribuyen al entendimiento del negocio (por ejemplo, qué indica un LTV alto o bajo). También podrías mostrar la distribución del LTV con un histograma para complementar.
#
# </div>

# %%
avg_order_value = orders['Revenue'].mean()
print(avg_order_value)
# Out:
# 4.999646930477041

# %%
ltv = orders.groupby('Uid')['Revenue'].sum().reset_index(name='LTV')
print(ltv.head())
# Out:
#                 Uid    LTV
# 0   313578113262317   0.55
# 1  1575281904278712   3.05
# 2  2429014661409475  73.33
# 3  2464366381792757   2.44
# 4  2551852515556206  10.99

# %%
top_ltv = ltv.sort_values(by='LTV', ascending=False).head(20)

plt.figure(figsize=(12, 6))
plt.bar(top_ltv['Uid'].astype(str), top_ltv['LTV'])
plt.title('Top 20 Usuarios por LTV')
plt.xlabel('Usuario')
plt.ylabel('LTV ($)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# 2.3 Marketing
costs_by_source = costs.groupby('source_id')['costs'].sum().reset_index()
print(costs_by_source)
# Out:
#    source_id      costs
# 0          1   20833.27
# 1          2   42806.04
# 2          3  141321.63
# 3          4   61073.60
# 4          5   51757.10
# 5          9    5517.49
# 6         10    5822.49

# %%
first_visits = visits.sort_values(by='Start Ts').drop_duplicates(subset='Uid')
acquired_users_by_source = first_visits.groupby('Source Id')['Uid'].nunique().reset_index(name='new_users')
print(acquired_users_by_source)
# Out:
#    Source Id  new_users
# 0          1       9469
# 1          2      17616
# 2          3      66116
# 3          4      72346
# 4          5      49237
# 5          6          2
# 6          7         32
# 7          9       6448
# 8         10       6903

# %%
cac = costs_by_source.merge(acquired_users_by_source, left_on='source_id', right_on='Source Id')
cac['CAC'] = cac['costs'] / cac['new_users']
print(cac)
# Out:
#    source_id      costs  Source Id  new_users       CAC
# 0          1   20833.27          1       9469  2.200155
# 1          2   42806.04          2      17616  2.429952
# 2          3  141321.63          3      66116  2.137480
# 3          4   61073.60          4      72346  0.844188
# 4          5   51757.10          5      49237  1.051183
# 5          9    5517.49          9       6448  0.855690
# 6         10    5822.49         10       6903  0.843472

# %%
user_sources = first_visits[['Uid', 'Source Id']]
orders = orders.merge(user_sources, on='Uid', how='left')
revenue_by_source = orders.groupby('Source Id')['Revenue'].sum().reset_index(name='total_revenue')

romi = revenue_by_source.merge(costs_by_source, left_on='Source Id', right_on='source_id')
romi['ROMI'] = (romi['total_revenue'] - romi['costs']) / romi['costs']
print(romi)
# Out:
#    Source Id  total_revenue  source_id      costs      ROMI
# 0          1       31090.55          1   20833.27  0.492351
# 1          2       46923.61          2   42806.04  0.096191
# 2          3       54511.24          3  141321.63 -0.614275
# 3          4       56696.83          4   61073.60 -0.071664
# 4          5       52624.02          5   51757.10  0.016750
# 5          9        5759.40          9    5517.49  0.043844
# 6         10        4450.33         10    5822.49 -0.235665

# %%
marketing_summary = cac.merge(romi[['Source Id', 'total_revenue', 'ROMI']], on='Source Id')
print(marketing_summary)
# Out:
#    source_id      costs  Source Id  new_users       CAC  total_revenue  \
# 0          1   20833.27          1       9469  2.200155       31090.55
# 1          2   42806.04          2      17616  2.429952       46923.61
# 2          3  141321.63          3      66116  2.137480       54511.24
# 3          4   61073.60          4      72346  0.844188       56696.83
# 4          5   51757.10          5      49237  1.051183       52624.02
# 5          9    5517.49          9       6448  0.855690        5759.40
# 6         10    5822.49         10       6903  0.843472        4450.33
#
#        ROMI
# 0  0.492351
# 1  0.096191
# 2 -0.614275
# 3 -0.071664
# 4  0.016750
# 5  0.043844
# 6 -0.235665

# %%
marketing_summary_sorted = marketing_summary.sort_values(by='Source Id')

plt.figure(figsize=(8, 4))
plt.bar(marketing_summary_sorted['Source Id'].astype(str), marketing_summary_sorted['CAC'])
plt.title('CAC (Costo de Adquisición de Clientes) por Fuente')
plt.xlabel('Source Id')
plt.ylabel('CAC ($)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.bar(marketing_summary_sorted['Source Id'].astype(str), marketing_summary_sorted['ROMI'])
plt.title('ROMI (Retorno de la Inversión en Marketing) por Fuente')
plt.xlabel('Source Id')
plt.ylabel('ROMI')
plt.axhline(0, color='gray', linestyle='--')  # Línea de referencia en 0
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente interpretación del ROMI como retorno sobre inversión. El gráfico con línea base en 0 ayuda a visualizar claramente qué fuentes son rentables y cuáles no. Buena aplicación del pensamiento analítico para tomar decisiones estratégicas sobre presupuesto.
#
# </div>

# %%
plt.figure(figsize=(8, 4))
plt.bar(marketing_summary_sorted['Source Id'].astype(str), marketing_summary_sorted['total_revenue'])
plt.title('Ingresos Totales por Fuente')
plt.xlabel('Source Id')
plt.ylabel('Ingresos ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# CONCLUSIONES
# Se recomienda invertir más en las fuentes que presentan un equilibrio saludable entre bajo CAC (Costo de Adquisición de Clientes) y alto ROMI (Retorno de la Inversión en Marketing). Según nuestro análisis, al menos una fuente (Source Id 1) demostró tener un CAC moderado y un ROMI positivo, lo que indica que genera ingresos por encima del gasto publicitario.
#
# Recomendaciones Estratégicas
# Reforzar inversión en las fuentes con ROMI positivo
#     Especialmente si también tienen un CAC razonable (menos de $2.50).
#     Estas fuentes han demostrado conversión y retorno, por lo tanto, son escalables.
#
# Evitar fuentes con ROMI negativo persistente
#     Invertir más en estas fuentes solo aumenta pérdidas.
#     Se puede hacer test A/B con ajustes creativos, pero con bajo presupuesto hasta ver mejoras.
#
# Monitorear las fuentes con CAC bajo pero ROMI ligeramente negativo
#     Si el CAC es bajo, hay espacio para trabajar la conversión (landing pages, ofertas, UX).
#
# Las métricas muestran que no todas las fuentes que generan muchos usuarios son rentables. Lo ideal no es solo atraer usuarios, sino atraer a los correctos. Se debe priorizar la inversión en las fuentes con retorno comprobado y usar pruebas controladas para mejorar otras plataformas antes de escalar el presupuesto.

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades! Tu proyecto está <b>aprobado</b>. Has demostrado un excelente manejo de los datos, análisis exploratorio, y cálculo de métricas clave en marketing digital. A continuación, destaco los puntos positivos y algunas áreas interesantes para seguir investigando:
#
# #### Puntos Positivos:
#
# * **Procesamiento de datos:** Muy buen uso de conversión de tipos, manejo de errores y agrupaciones temporales.
# * **Cálculo de métricas clave:** Incluiste todas las métricas relevantes (LTV, CAC, ROMI) y las interpretaste correctamente.
# * **Visualización:** Tus gráficos están bien etiquetados, escalados y son fáciles de interpretar.
#
# </div>
